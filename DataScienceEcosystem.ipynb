# %% [markdown]
# ## Author
#
# Seth Kooyman

# %% [markdown]
# ![11-authordetails.JPG](attachment:11-authordetails.JPG)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.jpg](attachment:2-title.jpg)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Objectives:
#    - List popular data science languages
#    - List essenital data science libraries
#    - List common data science tools

# %% [markdown]
# ![10-objectives.JPG](attachment:10-objectives.JPG)

# %% [markdown]
# ![3-intro.JPG](attachment:3-intro.JPG)

# %% [markdown]
# Some of the popular languages we use for data science are:
#
# | Popular Data Languages |
# | --------------------------------- |
# | Python |
# | Java Script |
# | SQL |
# | R |

# %% [markdown]
# ![4-dslanguages.JPG](attachment:4-dslanguages.JPG)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# |Data Science Libraries|
# |---|
# |TensorFlow|
# |Pandas|
# |Numpy|
# |SciPy|

# %% [markdown]
# ![5-dslibraries.JPG](attachment:5-dslibraries.JPG)

# %% [markdown]
# |Data Science Tools|
# |---|
# |Tableau|
# |MATLAB|
# |Jupyter|
# |MongoDB|

# %% [markdown]
# ![6-dstools.JPG](attachment:6-dstools.JPG)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.JPG](attachment:7-introarithmetic.JPG)

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.JPG](attachment:8-multiplyandaddintegers.JPG)

# %%
# This will convert 200 minutes to hours by diving by 60.

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.JPG](attachment:9-hourstominutes.JPG)
